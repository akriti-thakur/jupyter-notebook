# %% [markdown]
# DATA CLEANING

# %%
import pandas as pd
import numpy as n 
import matplotlib as m

# %%
first=pd.read_excel('C:/Users/akrit/OneDrive/Documents/cleaning.xlsx')
first
# first.info()
# first.describe()
first.to_csv('C:/Users/akrit/OneDrive/Documents/cleaning.csv')
first
# Out:
#                Player       Span  Mat   Inns  NO  Runs    HS    Ave     BF
# 0    DG Bradman (AUS)  1928-1948   52   80.0  10  6996   334  99.94  9800+  \
# 1      HC Brook (ENG)  2022-2023   12   20.0   1  1181   186  62.15   1287
# 2      AC Voges (AUS)  2015-2016   20   31.0   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23   41.0   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22   40.0   4  2190  270*  60.83   416+
# ..                ...        ...  ...    ...  ..   ...   ...    ...    ...
# 60  GC Smith (ICC/SA)  2002-2014  117  205.0  13  9265   277  48.25  15525
# 61  WH Ponsford (AUS)  1924-1934   29   48.0   4  2122   266  48.22  3118+
# 62    SJ McCabe (AUS)  1930-1938   39   62.0   5  2748   232  48.21  3217+
# 63   DR Jardine (ENG)  1928-1934   22   33.0   6  1296   127  48.00  2110+
# 64   DR Jardine (ENG)  1928-1934   22   33.0   6  1296   127  48.00  2110+
#
#        SR   100  50   0    4s  6s
# ...

# %%
firs=pd.read_csv('C:/Users/akrit/OneDrive/Documents/cleaning.csv',index_col=0)
firs
# Out:
#                Player       Span  Mat   Inns  NO  Runs    HS    Ave     BF
# 0    DG Bradman (AUS)  1928-1948   52   80.0  10  6996   334  99.94  9800+  \
# 1      HC Brook (ENG)  2022-2023   12   20.0   1  1181   186  62.15   1287
# 2      AC Voges (AUS)  2015-2016   20   31.0   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23   41.0   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22   40.0   4  2190  270*  60.83   416+
# ..                ...        ...  ...    ...  ..   ...   ...    ...    ...
# 60  GC Smith (ICC/SA)  2002-2014  117  205.0  13  9265   277  48.25  15525
# 61  WH Ponsford (AUS)  1924-1934   29   48.0   4  2122   266  48.22  3118+
# 62    SJ McCabe (AUS)  1930-1938   39   62.0   5  2748   232  48.21  3217+
# 63   DR Jardine (ENG)  1928-1934   22   33.0   6  1296   127  48.00  2110+
# 64   DR Jardine (ENG)  1928-1934   22   33.0   6  1296   127  48.00  2110+
#
#        SR   100  50   0    4s  6s
# ...

# %%
new_name=['Player','Span','Mat',"Inns",'Not_Out','Runs','Highest_innes_score','Ave','balls_faced','batting_strike_rate','hundreds_scored','fifties_scored','ducks_scored','boundary_fours','boundary_sixes']
firs.columns = new_name
firs
# Out:
#                Player       Span  Mat   Inns  Not_Out  Runs
# 0    DG Bradman (AUS)  1928-1948   52   80.0       10  6996  \
# 1      HC Brook (ENG)  2022-2023   12   20.0        1  1181
# 2      AC Voges (AUS)  2015-2016   20   31.0        7  1485
# 3     RG Pollock (SA)  1963-1970   23   41.0        4  2256
# 4     GA Headley (WI)  1930-1954   22   40.0        4  2190
# ..                ...        ...  ...    ...      ...   ...
# 60  GC Smith (ICC/SA)  2002-2014  117  205.0       13  9265
# 61  WH Ponsford (AUS)  1924-1934   29   48.0        4  2122
# 62    SJ McCabe (AUS)  1930-1938   39   62.0        5  2748
# 63   DR Jardine (ENG)  1928-1934   22   33.0        6  1296
# 64   DR Jardine (ENG)  1928-1934   22   33.0        6  1296
#
#    Highest_innes_score    Ave balls_faced  batting_strike_rate
# 0                  334  99.94       9800+                58.60  \
# 1                  186  62.15        1287                91.76
# ...

# %%
firs.isnull().sum()
# Out:
# Player                 0
# Span                   0
# Mat                    0
# Inns                   1
# Not_Out                0
# Runs                   0
# Highest_innes_score    0
# Ave                    0
# balls_faced            3
# batting_strike_rate    2
# hundreds_scored        1
# fifties_scored         0
# ducks_scored           0
# boundary_fours         0
# boundary_sixes         0
# dtype: int64

# %%
firs[firs['balls_faced'].isna()|firs['Inns'].isna()|firs['batting_strike_rate'].isna()|firs['hundreds_scored'].isna()]
# fir.columns
# Out:
#                   Player       Span  Mat   Inns  Not_Out   Runs
# 7    KF Barrington (ENG)  1955-1968   82    NaN       15   6806  \
# 8         ED Weekes (WI)  1948-1958   48   81.0        5   4455
# 11    KC Sangakkara (SL)  2000-2015  134  233.0       17  12400
# 13        JB Hobbs (ENG)  1908-1930   61  102.0        7   5410
# 15       CL Walcott (WI)  1948-1960   44   74.0        7   3798
# 30      RT Ponting (AUS)  1995-2012  168  287.0       29  13378
# 56  Hon.FS Jackson (ENG)  1893-1905   20   33.0        4   1415
#
#    Highest_innes_score    Ave balls_faced  batting_strike_rate
# 7                  256  58.67       4957+                42.42  \
# 8                  207  58.61         NaN                 0.00
# 11                 319  57.40       22882                54.19
# 13                 211  56.94       5363+                  NaN
# 15                 220  56.68         NaN                 0.00
# 30                 257  51.85       22782                  NaN
# ...

# %%
# fir['Inns']=fir['Inns'].fillna(0)
# fir['Inns'].isna()

# fir['balls_faced']=fir['balls_faced'].fillna(0)
# fir['batting_strike_rate']=fir['batting_strike_rate'].fillna(0)
# fir['hundreds_scored']=fir['hundreds_scored'].fillna(0)
# fir.columns[fir.isnull().any()]
# fir.isnull().any()
firs.fillna(0,inplace=True)
firs.isnull().any()
# Out:
# Player                 False
# Span                   False
# Mat                    False
# Inns                   False
# Not_Out                False
# Runs                   False
# Highest_innes_score    False
# Ave                    False
# balls_faced            False
# batting_strike_rate    False
# hundreds_scored        False
# fifties_scored         False
# ducks_scored           False
# boundary_fours         False
# boundary_sixes         False
# dtype: bool

# %%
dup=firs.duplicated()
dup
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 60    False
# 61    False
# 62    False
# 63    False
# 64     True
# Length: 65, dtype: bool

# %%
# # Identify all duplicated rows
# duplicated_rows = fir.duplicated(keep=False)

# # Use these rows to filter the DataFrame and then use `.any()` along axis=0 to check each column
# columns_with_duplicates = fir[duplicated_rows].columns[fir[duplicated_rows].any(axis=0)].tolist()

# # This will give you a list of column names that have duplicated values
# print(columns_with_duplicates)

column_names_with_duplicates = firs.columns[firs[firs.duplicated(keep=False)].any(axis=0)].tolist()
print(column_names_with_duplicates)
# Out:
# ['Player', 'Span', 'Mat', 'Inns', 'Not_Out', 'Runs', 'Highest_innes_score', 'Ave', 'balls_faced', 'batting_strike_rate', 'hundreds_scored', 'fifties_scored', 'ducks_scored', 'boundary_fours', 'boundary_sixes']

# %%
firs[firs['Player'].duplicated()]
# Out:
#               Player       Span  Mat   Inns  Not_Out  Runs
# 23    AD Nourse (SA)  1935-1951   34   62.0        7  2960  \
# 52     V Kohli (IND)  2011-2024  113  191.0       11  8848
# 64  DR Jardine (ENG)  1928-1934   22   33.0        6  1296
#
#    Highest_innes_score    Ave balls_faced  batting_strike_rate
# 23                 231  53.81        108+                63.88  \
# 52                254*  49.15       15924                55.56
# 64                 127  48.00       2110+                25.59
#
#     hundreds_scored  fifties_scored  ducks_scored boundary_fours
# 23              9.0              14             3           115+  \
# 52             29.0              30            14            991
# 64              1.0              10             2            53+
#
#    boundary_sixes
# 23              6
# 52             26
# 64              0

# %%
firs[firs['Player'].isin(['AD Nourse (SA)','V Kohli (IND)','DR Jardine (ENG)'])]
# Out:
#               Player       Span  Mat   Inns  Not_Out  Runs
# 14    AD Nourse (SA)  1935-1951   34   62.0        7  2960  \
# 23    AD Nourse (SA)  1935-1951   34   62.0        7  2960
# 49     V Kohli (IND)  2011-2024  113  191.0       11  8848
# 52     V Kohli (IND)  2011-2024  113  191.0       11  8848
# 63  DR Jardine (ENG)  1928-1934   22   33.0        6  1296
# 64  DR Jardine (ENG)  1928-1934   22   33.0        6  1296
#
#    Highest_innes_score    Ave balls_faced  batting_strike_rate
# 14                 231  53.81        108+                63.88  \
# 23                 231  53.81        108+                63.88
# 49                254*  49.15       15924                55.56
# 52                254*  49.15       15924                55.56
# 63                 127  48.00       2110+                25.59
# 64                 127  48.00       2110+                25.59
#
#     hundreds_scored  fifties_scored  ducks_scored boundary_fours
# ...

# %%
rem= firs.drop_duplicates(inplace=True)
# rem
firs.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 59    False
# 60    False
# 61    False
# 62    False
# 63    False
# Length: 62, dtype: bool

# %%
firs['Span'].str.split('-')
# Out:
# 0     [1928, 1948]
# 1     [2022, 2023]
# 2     [2015, 2016]
# 3     [1963, 1970]
# 4     [1930, 1954]
#           ...
# 59    [1965, 1981]
# 60    [2002, 2014]
# 61    [1924, 1934]
# 62    [1930, 1938]
# 63    [1928, 1934]
# Name: Span, Length: 62, dtype: object

# %%
firs['Rookie_year']=firs['Span'].str.split('-').str[0]
firs['Finale_year']=firs['Span'].str.split('-').str[1]
firs[['Rookie_year','Finale_year']]
# fir=fir.drop(['Span'],axis=1)
# Out:
#    Rookie_year Finale_year
# 0         1928        1948
# 1         2022        2023
# 2         2015        2016
# 3         1963        1970
# 4         1930        1954
# ..         ...         ...
# 59        1965        1981
# 60        2002        2014
# 61        1924        1934
# 62        1930        1938
# 63        1928        1934
#
# [62 rows x 2 columns]

# %%
firs['Player'].str.split('(')
firs['Country']=firs['Player'].str.split('(').str[1]
firs['Country']=firs['Country'].str.split(')').str[0]
firs
# Out:
#                Player       Span  Mat   Inns  Not_Out  Runs
# 0    DG Bradman (AUS)  1928-1948   52   80.0       10  6996  \
# 1      HC Brook (ENG)  2022-2023   12   20.0        1  1181
# 2      AC Voges (AUS)  2015-2016   20   31.0        7  1485
# 3     RG Pollock (SA)  1963-1970   23   41.0        4  2256
# 4     GA Headley (WI)  1930-1954   22   40.0        4  2190
# ..                ...        ...  ...    ...      ...   ...
# 59   KD Walters (AUS)  1965-1981   74  125.0       14  5357
# 60  GC Smith (ICC/SA)  2002-2014  117  205.0       13  9265
# 61  WH Ponsford (AUS)  1924-1934   29   48.0        4  2122
# 62    SJ McCabe (AUS)  1930-1938   39   62.0        5  2748
# 63   DR Jardine (ENG)  1928-1934   22   33.0        6  1296
#
#    Highest_innes_score    Ave balls_faced  batting_strike_rate
# 0                 None  99.94       9800+                58.60  \
# 1                 None  62.15        1287                91.76
# ...

# %%
firs['Highest_innes_score']=firs['Highest_innes_score'].fillna(0,inplace=True)
firs
# Out:
#                Player       Span  Mat   Inns  Not_Out  Runs
# 0    DG Bradman (AUS)  1928-1948   52   80.0       10  6996  \
# 1      HC Brook (ENG)  2022-2023   12   20.0        1  1181
# 2      AC Voges (AUS)  2015-2016   20   31.0        7  1485
# 3     RG Pollock (SA)  1963-1970   23   41.0        4  2256
# 4     GA Headley (WI)  1930-1954   22   40.0        4  2190
# ..                ...        ...  ...    ...      ...   ...
# 59   KD Walters (AUS)  1965-1981   74  125.0       14  5357
# 60  GC Smith (ICC/SA)  2002-2014  117  205.0       13  9265
# 61  WH Ponsford (AUS)  1924-1934   29   48.0        4  2122
# 62    SJ McCabe (AUS)  1930-1938   39   62.0        5  2748
# 63   DR Jardine (ENG)  1928-1934   22   33.0        6  1296
#
#    Highest_innes_score    Ave balls_faced  batting_strike_rate
# 0                 None  99.94       9800+                58.60  \
# 1                 None  62.15        1287                91.76
# ...

# %%
firs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 62 entries, 0 to 63
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Player               62 non-null     object
#  1   Span                 62 non-null     object
#  2   Mat                  62 non-null     int64
#  3   Inns                 62 non-null     float64
#  4   Not_Out              62 non-null     int64
#  5   Runs                 62 non-null     int64
#  6   Highest_innes_score  0 non-null      object
#  7   Ave                  62 non-null     float64
#  8   balls_faced          62 non-null     object
#  9   batting_strike_rate  62 non-null     float64
#  10  hundreds_scored      62 non-null     float64
#  11  fifties_scored       62 non-null     int64
#  12  ducks_scored         62 non-null     int64
#  13  boundary_fours       62 non-null     object
#  14  boundary_sixes       62 non-null     object
# ...

# %%
firs['Finale_year']=firs['Finale_year'].year
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[125], line 1
# ----> 1 firs['Finale_year']=firs['Finale_year'].year
#
# File c:\Python311\Lib\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'year'
