# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import datasets
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler

# %%
d=datasets.load_diabetes()
ro=pd.DataFrame(data=d.data,columns=d.feature_names)
# ro["target"]=d.target

# %%
X=ro
y=d.target

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=60) # type: ignore

# %%
# X_train
# y_train

# %%
#standarizing
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)
reg=LinearRegression()

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
ms=cross_val_score(reg,X_train,y_train,scoring='neg_mean_squared_log_error',cv=10)
np.mean(ms)
# Out:
# -0.1844038612030812

# %%
reg_pre=reg.predict(X_test)

# %%
reg_pre
# Out:
# array([172.60040851, 141.73845181, 138.10152366,  87.2632975 ,
#         66.93645312, 225.04254488, 187.73274972, 231.75098014,
#        216.77810833, 140.44409559, 127.07169846, 173.12814155,
#        116.47015052, 206.75068494, 153.00218188, 144.4146491 ,
#        102.77837227, 229.83828109, 133.09336442,  86.10076956,
#        201.89787329, 154.30377249, 214.47442723, 100.14919887,
#        164.22524412, 248.42815749, 227.01539186, 156.56323831,
#        148.10159716,  87.26360487, 183.94705025, 153.99539539,
#        120.24659526, 135.29499911, 151.05853681, 122.38998877,
#        144.35884571, 124.01081816, 111.08819429, 164.85734995,
#        174.27904628, 123.52160387,  94.29384007, 187.19821956,
#        174.85481345, 213.3347742 ,  63.34640694, 110.29906749,
#        115.98653762,  64.29319918,  95.61640715, 161.19173887,
#        260.16322756, 165.53741815, 205.36702832, 169.04029709,
#        177.56946385, 164.67004226, 228.32426579, 164.75413204,
# ...

# %%
sns.displot(reg_pre-y_test,kind="kde")

# %% [markdown]
# # new exercise

# %%
da= pd.read_csv("C:/Users/akrit/Downloads/canada_per_capita_income.csv")

# %%
da
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
plt.xlabel("year")
plt.ylabel("income")

plt.scatter(data=da,x="year",y="per capita income (US$)",color='red',marker="*")
plt.show()

# %%
x= da.drop('year',axis=1)

# %%
x
# Out:
#     per capita income (US$)
# 0               3399.299037
# 1               3768.297935
# 2               4251.175484
# 3               4804.463248
# 4               5576.514583
# 5               5998.144346
# 6               7062.131392
# 7               7100.126170
# 8               7247.967035
# 9               7602.912681
# 10              8355.968120
# 11              9434.390652
# 12              9619.438377
# 13             10416.536590
# 14             10790.328720
# 15             11018.955850
# 16             11482.891530
# 17             12974.806620
# 18             15080.283450
# 19             16426.725480
# 20             16838.673200
# 21             17266.097690
# 22             16412.083090
# 23             15875.586730
# 24             15755.820270
# 25             16369.317250
# 26             16699.826680
# 27             17310.757750
# 28             16622.671870
# 29             17581.024140
# 30             18987.382410
# 31             18601.397240
# ...

# %%
y= da.drop('per capita income (US$)',axis=1)

# %%
y
# Out:
#     year
# 0   1970
# 1   1971
# 2   1972
# 3   1973
# 4   1974
# 5   1975
# 6   1976
# 7   1977
# 8   1978
# 9   1979
# 10  1980
# 11  1981
# 12  1982
# 13  1983
# 14  1984
# 15  1985
# 16  1986
# 17  1987
# 18  1988
# 19  1989
# 20  1990
# 21  1991
# 22  1992
# 23  1993
# 24  1994
# 25  1995
# 26  1996
# 27  1997
# 28  1998
# 29  1999
# 30  2000
# 31  2001
# 32  2002
# 33  2003
# 34  2004
# 35  2005
# 36  2006
# 37  2007
# 38  2008
# 39  2009
# 40  2010
# 41  2011
# 42  2012
# 43  2013
# 44  2014
# 45  2015
# 46  2016

# %%
reg= LinearRegression()

# %%
reg.fit(y,x)
# Out:
# LinearRegression()

# %%
year = np.array([2020]).reshape(-1, 1)

prediction = reg.predict(year)
# Out:
# [[41288.69409442]]
# c:\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print("the accuracy is :",reg.score(y,x))
# Out:
# the accuracy is  0.890916917957032

# %%
print(prediction)
# Out:
# [[41288.69409442]]

# %%
df=[2024,2025,2089]
mm= np.array(df).reshape(-1,1)
p= reg.predict(mm)
# Out:
# c:\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
dataframe= pd.DataFrame({"year":[df],"income":[p]})

# %%
dataframe
# Out:
#                  year                                             income
# 0  [2024, 2025, 2089]  [[44602.554395308485], [45431.01947053103], [9...
