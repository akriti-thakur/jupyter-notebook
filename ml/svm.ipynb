# %%
import pandas as pd
from sklearn.datasets import load_iris
pd.set_option('display.max_columns',None)
pd.set_option('display.max_colwidth',None)
pd.set_option('display.max_rows', None)
import numpy as np

# %%
iris= load_iris()

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
dir(iris)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
iris.data
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
df= pd.DataFrame(data=iris.data,columns=iris.feature_names)

# %%
df.head(10)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
# 5                5.4               3.9                1.7               0.4
# 6                4.6               3.4                1.4               0.3
# 7                5.0               3.4                1.5               0.2
# 8                4.4               2.9                1.4               0.2
# 9                4.9               3.1                1.5               0.1

# %%
df['target'] = iris.target
df.head(3)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
#
#    target
# 0       0
# 1       0
# 2       0

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
df[df.target==2]
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 100                6.3               3.3                6.0               2.5
# 101                5.8               2.7                5.1               1.9
# 102                7.1               3.0                5.9               2.1
# 103                6.3               2.9                5.6               1.8
# 104                6.5               3.0                5.8               2.2
# 105                7.6               3.0                6.6               2.1
# 106                4.9               2.5                4.5               1.7
# 107                7.3               2.9                6.3               1.8
# 108                6.7               2.5                5.8               1.8
# 109                7.2               3.6                6.1               2.5
# 110                6.5               3.2                5.1               2.0
# ...

# %%
# df["flower_name"]=df.target.apply(lambda x: iris.target_names[x])
def get_flower_name(target):
    return iris.target_names[target]

df["flower_name"] = df.target.apply(get_flower_name)

# %%
df.head(5)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target flower_name
# 0       0      setosa
# 1       0      setosa
# 2       0      setosa
# 3       0      setosa
# 4       0      setosa

# %%
df0= df[df.target==0]
df1= df[df.target==1]
df2= df[df.target==2]

# %%
# df2

# %%
from matplotlib import pyplot as plt

# %%
plt.xlabel('sepal_length')
plt.ylabel('sepal_width')

plt.scatter(df0['sepal length (cm)'],df1["sepal width (cm)"],color='green',marker="*")

plt.scatter(df1['sepal length (cm)'],df2["sepal width (cm)"],color='red',marker="+")
# plt.scatter(df2['sepal length (cm)'],df0["sepal width (cm)"],color='yellow',marker=".")

plt.show()

# %%
plt.scatter(df0['petal length (cm)'],df1["petal width (cm)"],color='green',marker="*")
plt.scatter(df1['petal length (cm)'],df0["petal width (cm)"],color='red',marker="*")
# plt.scatter(df2['petal length (cm)'],df0["petal width (cm)"],color='yellow',marker="*")
# plt.scatter(df2['petal length (cm)'],df1["petal width (cm)"],color='black',marker="*")


plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
X= df.drop(columns=['target','flower_name'],axis=1)

# %%
y= df["target"]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing

# %%
scaler = StandardScaler()
x = scaler.fit_transform(X)
# x

# %%
if isinstance(y, np.ndarray):
    print("already an array ")
    
    
else:
    y=np.array(y)

# %%
 = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

# %%
sup = SVC()

# %%
parameters = {'kernel':('linear', 'rbf','poly', 'sigmoid'),
              'C': np.logspace(-3, 3, 5),
              'gamma':np.logspace(-3, 3, 5)}

# %%
svm_cvs=  GridSearchCV(sup,parameters,cv=5)

# %%
svm_cvs.fit(X_test,y_test)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': array([1.00000000e-03, 3.16227766e-02, 1.00000000e+00, 3.16227766e+01,
#        1.00000000e+03]),
#                          'gamma': array([1.00000000e-03, 3.16227766e-02, 1.00000000e+00, 3.16227766e+01,
#        1.00000000e+03]),
#                          'kernel': ('linear', 'rbf', 'poly', 'sigmoid')})

# %%
# print(X_test.shape)
# print(y_test.shape)
# Out:
# (30, 4)
# (30,)

# %%
accu=svm_cvs.score(X_test,y_test)

# %%
svm_predic= svm_cvs.predict(X_test)

# %%
print(svm_cvs.best_score_)
# Out:
# 0.9666666666666668

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

def plot_confusion_matrix(y,y_predict):
    

    cm = confusion_matrix(y, y_predict)
    ax= plt.subplot()
    sns.heatmap(cm, annot=True, ax = ax); #annot=True to annotate cells
    ax.set_xlabel('Predicted labels')
    ax.set_ylabel('True labels')
    ax.set_title('Confusion Matrix'); 
    # ax.xaxis.set_ticklabels(['non-cancerous', 'cancer']); ax.yaxis.set_ticklabels(['non-cancerous', 'cancer']) 
    plt.show()

# %%
plot_confusion_matrix(y_test,svm_predic)
