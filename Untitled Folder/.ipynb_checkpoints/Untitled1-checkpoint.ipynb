# %%
import pandas as pd 
import numpy as n
import seaborn as s
import matplotlib.pyplot as pl

# %%
c= pd.read_csv("C:/Users/akrit/Downloads/Book1.csv")

# %%
c
# Out:
#      Invoice ID Branch      City Customer type  Gender
# 0   692-92-5582      B  Mandalay        Member  Female  \
# 1   351-62-0822      B  Mandalay        Member  Female
# 2   529-56-3974      B  Mandalay        Member    Male
# 3   299-46-1805      B  Mandalay        Member  Female
# 4   319-50-3348      B  Mandalay        Normal  Female
# 5   371-85-5789      B  Mandalay        Normal    Male
# 6   273-16-6619      B  Mandalay        Normal    Male
# 7   649-29-6775      B  Mandalay        Normal    Male
# 8   145-94-9061      B  Mandalay        Normal  Female
# 9   871-79-8483      B  Mandalay        Normal    Male
# 10  149-71-6266      B  Mandalay        Member    Male
# 11  640-49-2076      B  Mandalay        Normal    Male
# 12  777-82-7220      B  Mandalay        Member    Male
# 13  280-35-5823      B  Mandalay        Member  Female
# 14  354-25-5821      B  Mandalay        Member  Female
# 15  132-32-9879      B  Mandalay        Member  Female
# ...

# %%
c.shape
# Out:
# (51, 17)

# %%
c.head(30)
# Out:
#      Invoice ID Branch      City Customer type  Gender
# 0   692-92-5582      B  Mandalay        Member  Female  \
# 1   351-62-0822      B  Mandalay        Member  Female
# 2   529-56-3974      B  Mandalay        Member    Male
# 3   299-46-1805      B  Mandalay        Member  Female
# 4   319-50-3348      B  Mandalay        Normal  Female
# 5   371-85-5789      B  Mandalay        Normal    Male
# 6   273-16-6619      B  Mandalay        Normal    Male
# 7   649-29-6775      B  Mandalay        Normal    Male
# 8   145-94-9061      B  Mandalay        Normal  Female
# 9   871-79-8483      B  Mandalay        Normal    Male
# 10  149-71-6266      B  Mandalay        Member    Male
# 11  640-49-2076      B  Mandalay        Normal    Male
# 12  777-82-7220      B  Mandalay        Member    Male
# 13  280-35-5823      B  Mandalay        Member  Female
# 14  354-25-5821      B  Mandalay        Member  Female
# 15  132-32-9879      B  Mandalay        Member  Female
# ...

# %%
d =c.head(15)

# %%
d.to_csv("C:/Users/akrit/Downloads/mmmm.csv",index = False)

# %%
d
# Out:
#      Invoice ID Branch      City Customer type  Gender
# 0   692-92-5582      B  Mandalay        Member  Female  \
# 1   351-62-0822      B  Mandalay        Member  Female
# 2   529-56-3974      B  Mandalay        Member    Male
# 3   299-46-1805      B  Mandalay        Member  Female
# 4   319-50-3348      B  Mandalay        Normal  Female
# 5   371-85-5789      B  Mandalay        Normal    Male
# 6   273-16-6619      B  Mandalay        Normal    Male
# 7   649-29-6775      B  Mandalay        Normal    Male
# 8   145-94-9061      B  Mandalay        Normal  Female
# 9   871-79-8483      B  Mandalay        Normal    Male
# 10  149-71-6266      B  Mandalay        Member    Male
# 11  640-49-2076      B  Mandalay        Normal    Male
# 12  777-82-7220      B  Mandalay        Member    Male
# 13  280-35-5823      B  Mandalay        Member  Female
# 14  354-25-5821      B  Mandalay        Member  Female
#
#               Product line  Unit price  Quantity   Tax 5%     Total
# ...

# %%
d.shape
# Out:
# (15, 17)

# %%
ss =pd.read_excel("C:/Users/akrit/Downloads/supermarket_sales.xlsx",header=1)

# %%
ss
# Out:
#      692-92-5582  B  Mandalay  Member  Female      Food_and_beverages  54.84
# 0    351-62-0822  B  Mandalay  Member  Female     Fashion_accessories  14.48  \
# 1    529-56-3974  B  Mandalay  Member    Male  Electronic_accessories  25.51
# 2    299-46-1805  B  Mandalay  Member  Female       Sports_and_travel  93.72
# 3    319-50-3348  B  Mandalay  Normal  Female      Home_and_lifestyle  40.30
# 4    371-85-5789  B  Mandalay  Normal    Male       Health_and_beauty  87.98
# ..           ... ..       ...     ...     ...                     ...    ...
# 994  886-18-2897  A    Yangon  Normal  Female      Food_and_beverages  56.56
# 995  745-74-0715  A    Yangon  Normal    Male  Electronic_accessories  58.03
# 996  727-02-1313  A    Yangon  Member    Male      Food_and_beverages  31.84
# 997  347-56-2442  A    Yangon  Normal    Male      Home_and_lifestyle  65.82
# 998  849-09-3807  A    Yangon  Member  Female     Fashion_accessories  88.34
#
# ...

# %%
ss.shape
# Out:
# (999, 17)

# %%
sss =pd.read_csv("m.csv")

# %%
sss
# Out:
#     name      jj  marks
# 0  hello      as     60
# 1  mello      ss     90
# 2     he  ssasad     89

# %%
sss.shape
# Out:
# (3, 3)

# %%
f =pd.read_csv("C:/Users/akrit/Downloads/x.txt",engine= 'python',sep='-')

# %%
f
# Out:
#      name  marks  roll_number
# 0  akriti     99            4
# 1  rohini     89           10
# 2  sristi    100            9
# 3   rahul     66            7

# %%
emp_header =bb
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 emp_header =bb
#
# NameError: name 'bb' is not defined

# %%
emp_header

# %%
 df_prfx=pd.read_csv("C:/Users/akrit/Downloads/mmmm.csv")

# %%
tt = df_prfx.head(5)

# %%
tt
# Out:
#     Invoice ID Branch      City Customer type  Gender            Product line
# 0  692-92-5582      B  Mandalay        Member  Female      Food_and_beverages  \
# 1  351-62-0822      B  Mandalay        Member  Female     Fashion_accessories
# 2  529-56-3974      B  Mandalay        Member    Male  Electronic_accessories
# 3  299-46-1805      B  Mandalay        Member  Female       Sports_and_travel
# 4  319-50-3348      B  Mandalay        Normal  Female      Home_and_lifestyle
#
#    Unit price  Quantity  Tax 5%    Total        Date   Time      Payment
# 0       54.84         3   8.226  172.746   2/20/2019  13:27  Credit card  \
# 1       14.48         4   2.896   60.816  02-06-2019  18:07      Ewallet
# 2       25.51         4   5.102  107.142  03-09-2019  17:03         Cash
# 3       93.72         6  28.116  590.436   1/15/2019  16:19         Cash
# 4       40.30         2   4.030   84.630  03-11-2019  15:30      Ewallet
#
#      cogs  gross margin percentage  gross income  Rating
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 tt[["Branch","Quantity","gross income"]].sum()
#
# NameError: name 'tt' is not defined

# %% [markdown]
# ##

# %% [raw]
# tt.sort_values(by=[""])
