# %%
import pandas as pd
import numpy as n

# %% [markdown]
# import numpy as n
# import seaborn as s
# import matplotlib.pyplot as pl

# %%
c= pd.read_csv("C:/Users/akrit/Downloads/Book1.csv")

# %%
c
# Out:
#      Invoice ID Branch      City Customer type  Gender
# 0   692-92-5582      B  Mandalay        Member  Female  \
# 1   351-62-0822      B  Mandalay        Member  Female
# 2   529-56-3974      B  Mandalay        Member    Male
# 3   299-46-1805      B  Mandalay        Member  Female
# 4   319-50-3348      B  Mandalay        Normal  Female
# 5   371-85-5789      B  Mandalay        Normal    Male
# 6   273-16-6619      B  Mandalay        Normal    Male
# 7   649-29-6775      B  Mandalay        Normal    Male
# 8   145-94-9061      B  Mandalay        Normal  Female
# 9   871-79-8483      B  Mandalay        Normal    Male
# 10  149-71-6266      B  Mandalay        Member    Male
# 11  640-49-2076      B  Mandalay        Normal    Male
# 12  777-82-7220      B  Mandalay        Member    Male
# 13  280-35-5823      B  Mandalay        Member  Female
# 14  354-25-5821      B  Mandalay        Member  Female
# 15  132-32-9879      B  Mandalay        Member  Female
# ...

# %%
c['duplicate'] = c.duplicated(keep=False).map[{True:'yes', False:'no}]
                                               c
# Out:
#   Cell In[4], line 1
#     c['duplicate'] = c.duplicated(keep=False).map[{True:'yes', False:'no}]
#                                                                      ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
c highlight_dups(var):
    return ['background-color:red' if x else '' for x in var.duplicated()]
# Out:
#   Cell In[5], line 1
#     c highlight_dups(var):
#       ^
# SyntaxError: invalid syntax

# %%
c.style.apply(highlight_dups)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 c.style.apply(highlight_dups)
#
# NameError: name 'highlight_dups' is not defined

# %%
c.shape

# %%
c.head(30)

# %%
lol=pd.read_csv("C:/Users/akrit/Downloads/book1.csv")

# %%
mm = lol[['Branch','City','Unit price']].head()

# %%
mm
# Out:
#   Branch      City  Unit price
# 0      B  Mandalay       54.84
# 1      B  Mandalay       14.48
# 2      B  Mandalay       25.51
# 3      B  Mandalay       93.72
# 4      B  Mandalay       40.30

# %%
mm.drop('Branch',axis =1,inplace = False)
# Out:
#        City  Unit price
# 0  Mandalay       54.84
# 1  Mandalay       14.48
# 2  Mandalay       25.51
# 3  Mandalay       93.72
# 4  Mandalay       40.30

# %%
mm
# Out:
#   Branch      City  Unit price
# 0      B  Mandalay       54.84
# 1      B  Mandalay       14.48
# 2      B  Mandalay       25.51
# 3      B  Mandalay       93.72
# 4      B  Mandalay       40.30

# %%
mm['Branch'] = ['S','S','l','l','k']

# %%
mm
# Out:
#   Branch      City  Unit price
# 0      S  Mandalay       54.84
# 1      S  Mandalay       14.48
# 2      l  Mandalay       25.51
# 3      l  Mandalay       93.72
# 4      k  Mandalay       40.30

# %%
mm_copy= mm.copy(deep=True)

# %% [markdown]
# mm_copy

# %%
mm_copy['Unit price']=[454.67,0.324678,2124,356,3246.990]

# %%
mm_copy
# Out:
#   Branch      City   Unit price
# 0      S  Mandalay   454.670000
# 1      S  Mandalay     0.324678
# 2      l  Mandalay  2124.000000
# 3      l  Mandalay   356.000000
# 4      k  Mandalay  3246.990000

# %%
c.head(10)
# Out:
#     Invoice ID Branch      City Customer type  Gender            Product line
# 0  692-92-5582      B  Mandalay        Member  Female      Food_and_beverages  \
# 1  351-62-0822      B  Mandalay        Member  Female     Fashion_accessories
# 2  529-56-3974      B  Mandalay        Member    Male  Electronic_accessories
# 3  299-46-1805      B  Mandalay        Member  Female       Sports_and_travel
# 4  319-50-3348      B  Mandalay        Normal  Female      Home_and_lifestyle
# 5  371-85-5789      B  Mandalay        Normal    Male       Health_and_beauty
# 6  273-16-6619      B  Mandalay        Normal    Male      Home_and_lifestyle
# 7  649-29-6775      B  Mandalay        Normal    Male     Fashion_accessories
# 8  145-94-9061      B  Mandalay        Normal  Female      Food_and_beverages
# 9  871-79-8483      B  Mandalay        Normal    Male     Fashion_accessories
#
#    Unit price  Quantity   Tax 5%     Total        Date   Time      Payment
# ...

# %%
c.tail(10)
# Out:
#      Invoice ID Branch      City Customer type  Gender
# 41  590-83-4591      B  Mandalay        Member    Male  \
# 42  241-72-9525      B  Mandalay        Normal    Male
# 43  262-47-2794      B  Mandalay        Member    Male
# 44  608-96-3517      B  Mandalay        Member  Female
# 45  279-74-2924      B  Mandalay        Member    Male
# 46  307-85-2293      B  Mandalay        Normal    Male
# 47  743-04-1105      B  Mandalay        Member    Male
# 48  423-57-2993      B  Mandalay        Normal    Male
# 49  548-46-9322      B  Mandalay        Normal    Male
# 50  505-02-0892      B  Mandalay        Member    Male
#
#               Product line  Unit price  Quantity   Tax 5%     Total
# 41  Electronic_accessories       87.45         6  26.2350  550.9350  \
# 42       Sports_and_travel       51.91        10  25.9550  545.0550
# 43      Home_and_lifestyle       71.86         8  28.7440  603.6240
# 44     Fashion_accessories       91.54         4  18.3080  384.4680
# ...

# %%
c.drop(['Invoice ID','Customer type'] ,axis=1,inplace= True)

# %%
c.tail()
# Out:
#    Branch      City Gender        Product line  Unit price  Quantity  Tax 5%
# 46      B  Mandalay   Male  Home_and_lifestyle       50.28         5  12.570  \
# 47      B  Mandalay   Male   Health_and_beauty       97.22         9  43.749
# 48      B  Mandalay   Male   Sports_and_travel       93.39         6  28.017
# 49      B  Mandalay   Male  Food_and_beverages       39.90        10  19.950
# 50      B  Mandalay   Male   Health_and_beauty       42.57         8  17.028
#
#       Total        Date   Time      Payment    cogs  gross margin percentage
# 46  263.970  03-07-2019  13:58      Ewallet  251.40                 4.761905  \
# 47  918.729   3/30/2019  14:43      Ewallet  874.98                 4.761905
# 48  588.357   3/27/2019  19:18      Ewallet  560.34                 4.761905
# 49  418.950   2/20/2019  15:24  Credit card  399.00                 4.761905
# 50  357.588   2/25/2019  14:12      Ewallet  340.56                 4.761905
#
#     gross income  Rating
# ...

# %%
cc = c.tail()

# %%
cc
# Out:
#    Branch      City Gender        Product line  Unit price  Quantity  Tax 5%
# 46      B  Mandalay   Male  Home_and_lifestyle       50.28         5  12.570  \
# 47      B  Mandalay   Male   Health_and_beauty       97.22         9  43.749
# 48      B  Mandalay   Male   Sports_and_travel       93.39         6  28.017
# 49      B  Mandalay   Male  Food_and_beverages       39.90        10  19.950
# 50      B  Mandalay   Male   Health_and_beauty       42.57         8  17.028
#
#       Total        Date   Time      Payment    cogs  gross margin percentage
# 46  263.970  03-07-2019  13:58      Ewallet  251.40                 4.761905  \
# 47  918.729   3/30/2019  14:43      Ewallet  874.98                 4.761905
# 48  588.357   3/27/2019  19:18      Ewallet  560.34                 4.761905
# 49  418.950   2/20/2019  15:24  Credit card  399.00                 4.761905
# 50  357.588   2/25/2019  14:12      Ewallet  340.56                 4.761905
#
#     gross income  Rating
# ...

# %%
cc
# Out:
#    Branch      City Gender        Product line  Unit price  Quantity  Tax 5%
# 46      B  Mandalay   Male  Home_and_lifestyle       50.28         5  12.570  \
# 47      B  Mandalay   Male   Health_and_beauty       97.22         9  43.749
# 48      B  Mandalay   Male   Sports_and_travel       93.39         6  28.017
# 49      B  Mandalay   Male  Food_and_beverages       39.90        10  19.950
# 50      B  Mandalay   Male   Health_and_beauty       42.57         8  17.028
#
#       Total        Date   Time      Payment    cogs  gross margin percentage
# 46  263.970  03-07-2019  13:58      Ewallet  251.40                 4.761905  \
# 47  918.729   3/30/2019  14:43      Ewallet  874.98                 4.761905
# 48  588.357   3/27/2019  19:18      Ewallet  560.34                 4.761905
# 49  418.950   2/20/2019  15:24  Credit card  399.00                 4.761905
# 50  357.588   2/25/2019  14:12      Ewallet  340.56                 4.761905
#
#     gross income  Rating
# ...

# %%
cc.loc[0,5]="customer_type"

# %%
cc
# Out:
#    Branch      City Gender        Product line  Unit price  Quantity  Tax 5%
# 46      B  Mandalay   Male  Home_and_lifestyle       50.28       5.0  12.570  \
# 47      B  Mandalay   Male   Health_and_beauty       97.22       9.0  43.749
# 48      B  Mandalay   Male   Sports_and_travel       93.39       6.0  28.017
# 49      B  Mandalay   Male  Food_and_beverages       39.90      10.0  19.950
# 50      B  Mandalay   Male   Health_and_beauty       42.57       8.0  17.028
# 0     NaN       NaN    NaN                 NaN         NaN       NaN     NaN
#
#       Total        Date   Time      Payment    cogs  gross margin percentage
# 46  263.970  03-07-2019  13:58      Ewallet  251.40                 4.761905  \
# 47  918.729   3/30/2019  14:43      Ewallet  874.98                 4.761905
# 48  588.357   3/27/2019  19:18      Ewallet  560.34                 4.761905
# 49  418.950   2/20/2019  15:24  Credit card  399.00                 4.761905
# ...

# %%
c[c.customer_type.str.startswith("n")][["Unit price","Gender"]]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 c[c.customer_type.str.startswith("n")][["Unit price","Gender"]]
#
# File C:\Python311\Lib\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'customer_type'

# %%
cc.nsmallest(2,"Unit price")

# %%
c.query['Unit price'>='30']

# %%
c.index

# %%
c[c.Gender.str.startswith("M")][["Unit price","Gender"]]

# %%
c.nsmallest(7,"Unit price")

# %%
c['mm']=c['Payment'].str.isnumeric()
c

# %%
code=c['Gender'].str.get_dummies()
code

# %%
d=pd.concat([c,code['Male']],axis =1)
d

# %%
d2=d[d.Male!= 0]
d2

# %%
dm=c.loc[1:6].reset_index(drop=True)

# %%
m=c.loc[9:17]

# %%
mmm=c.loc[30:45]

# %%
dam=pd.concat([dm,m])

dam

# %%
c.groupby(['Gender','Payment']).agg({"Quantity":["sum","min"],"cogs":"min"})

# %%
dam.isna().sum()

# %% [markdown]
#  c["counter"]=c.groupby("Gender").cumcount()
# c.sort_values(by=["counter"])
