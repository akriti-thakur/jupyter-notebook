# %%
import pandas as p

# %%
s=p.read_csv("C:/Users/akrit/Downloads/dup_columns.csv",header=None,prefix="lol_")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 s=p.read_csv("C:/Users/akrit/Downloads/dup_columns.csv",header=None,prefix="lol_")
#
# TypeError: read_csv() got an unexpected keyword argument 'prefix'

# %%
s.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 s.shape
#
# NameError: name 's' is not defined

# %%
s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 s
#
# NameError: name 's' is not defined

# %%
m=s[["first_name","id","age","employee_title","department"]].head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 m=s[["first_name","id","age","employee_title","department"]].head(5)
#
# NameError: name 's' is not defined

# %%
m
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 m
#
# NameError: name 'm' is not defined

# %%
m.to_excel("C:/Users/akrit/Downloads/mm.xlsx",index=False)

# %%
m=p.read_csv("C:/Users/akrit/Downloads/x.txt",header=None,prefix='n_')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 m=p.read_csv("C:/Users/akrit/Downloads/x.txt",header=None,prefix='n_')
#
# TypeError: read_csv() got an unexpected keyword argument 'prefix'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 m=s[(header==None,prefix=='_emp')].head(5)
#
# NameError: name 'header' is not defined
