# %%
import pandas as pd
import numpy as n

# %%
s = pd.read_csv("C:/Users/akrit/Downloads/Orders.csv")

# %%
s
# Out:
#     Order_ID  Order_Date CustomerName             State     City
# 0    B-26055  10-03-2018    Harivansh     Uttar Pradesh  Mathura
# 1    B-25993  03-02-2018       Madhav             Delhi    Delhi
# 2    B-25973  24-01-2018  Madan Mohan     Uttar Pradesh  Mathura
# 3    B-25923  27-12-2018        Gopal       Maharashtra   Mumbai
# 4    B-25757  21-08-2018     Vishakha    Madhya Pradesh   Indore
# ..       ...         ...          ...               ...      ...
# 495  B-25742  03-08-2018       Ashwin               Goa      Goa
# 496  B-26088  26-03-2018       Bhavna            Sikkim  Gangtok
# 497  B-25707  01-07-2018      Shivani       Maharashtra   Mumbai
# 498  B-25758  22-08-2018      Shubham  Himachal Pradesh    Simla
# 499  B-26095  28-03-2018      Monisha         Rajasthan   Jaipur
#
# [500 rows x 5 columns]

# %%
highlight_dups(var):
    return ['background-color:red' if x else '' for x in var.duplicated]
# Out:
#   Cell In[4], line 1
#     highlight_dups(var):
#                        ^
# SyntaxError: invalid syntax

# %%
s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order_ID      500 non-null    object
#  1   Order_Date    500 non-null    object
#  2   CustomerName  500 non-null    object
#  3   State         500 non-null    object
#  4   City          500 non-null    object
# dtypes: object(5)
# memory usage: 19.7+ KB

# %%
m=s[['Order_ID','State']].head(5)

# %%
m1=m.head(20)

# %%
m2 =m.tail(20)

# %%
m1
# Out:
#   Order_ID           State
# 0  B-26055   Uttar Pradesh
# 1  B-25993           Delhi
# 2  B-25973   Uttar Pradesh
# 3  B-25923     Maharashtra
# 4  B-25757  Madhya Pradesh

# %%
m2
# Out:
#   Order_ID           State
# 0  B-26055   Uttar Pradesh
# 1  B-25993           Delhi
# 2  B-25973   Uttar Pradesh
# 3  B-25923     Maharashtra
# 4  B-25757  Madhya Pradesh

# %%
join = m1.join(m2,lsuffix='__left',rsuffix='__right',how="outer")

# %%
join
# Out:
#   Order_ID           State Order_ID__right    State__right
# 0  B-26055   Uttar Pradesh         B-26055   Uttar Pradesh
# 1  B-25993           Delhi         B-25993           Delhi
# 2  B-25973   Uttar Pradesh         B-25973   Uttar Pradesh
# 3  B-25923     Maharashtra         B-25923     Maharashtra
# 4  B-25757  Madhya Pradesh         B-25757  Madhya Pradesh

# %%
mm=pd.concat([m1,m2])
ignore_index=True

# %%
mm
# Out:
#   Order_ID           State
# 0  B-26055   Uttar Pradesh
# 1  B-25993           Delhi
# 2  B-25973   Uttar Pradesh
# 3  B-25923     Maharashtra
# 4  B-25757  Madhya Pradesh
# 0  B-26055   Uttar Pradesh
# 1  B-25993           Delhi
# 2  B-25973   Uttar Pradesh
# 3  B-25923     Maharashtra
# 4  B-25757  Madhya Pradesh

# %%
m.set_index("Order_ID")
# Out:
#                    State
# Order_ID
# B-26055    Uttar Pradesh
# B-25993            Delhi
# B-25973    Uttar Pradesh
# B-25923      Maharashtra
# B-25757   Madhya Pradesh

# %%
s.rows=s.rows.str.upper()
s.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 s.rows=s.rows.str.upper()
#       2 s.head()
#
# File C:\Python311\Lib\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'rows'

# %%
s['mm']=s['STATE'].str.count("Delhi")
s.head()

# %%
s1= mm.head()

# %%
s2 = mm.tail()

# %%
s1
# Out:
#   Order_ID           State
# 0  B-26055   Uttar Pradesh
# 1  B-25993           Delhi
# 2  B-25973   Uttar Pradesh
# 3  B-25923     Maharashtra
# 4  B-25757  Madhya Pradesh

# %%
pd.merge(s1,s2,on ='Order_ID',how='natural')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 pd.merge(s1,s2,on ='Order_ID',how='natural')
#
# File C:\Python311\Lib\site-packages\pandas\core\reshape\merge.py:156, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     125 @Substitution("\nleft : DataFrame or named Series")
#     126 @Appender(_merge_doc, indents=0)
#     127 def merge(
#    (...)
#     140     validate: str | None = None,
#     141 ) -> DataFrame:
#     142     op = _MergeOperation(
#     143         left,
#     144         right,
#    (...)
#     154         validate=validate,
#     155     )
# --> 156     return op.get_result(copy=copy)
#
# File C:\Python311\Lib\site-packages\pandas\core\reshape\merge.py:803, in _MergeOperation.get_result(self, copy)
#     800 if self.indicator:
# ...

# %%
s[s.duplicated(subset=['Order_Date'])].head(60)
# Out:
#     Order_ID  Order_Date CustomerName              State                City
# 11   B-25969  21-01-2018     Shreyshi            Gujarat               Surat
# 54   B-25855  08-11-2018     Abhijeet     Madhya Pradesh              Bhopal
# 56   B-25995  04-02-2018       Yohann              Delhi               Delhi
# 61   B-25601  01-04-2018       Bharat            Gujarat           Ahmedabad
# 72   B-25730  22-07-2018      Rishabh          Rajasthan              Jaipur
# 85   B-25728  22-07-2018      Ameesha        Maharashtra                Pune
# 91   B-25838  29-10-2018      Sanjana     Madhya Pradesh              Indore
# 93   B-25952  13-01-2018     Priyanka     Madhya Pradesh              Indore
# 100  B-25813  10-10-2018  Hrisheekesh        Maharashtra              Mumbai
# 102  B-25954  14-01-2018       Trupti            Gujarat           Ahmedabad
# 106  B-25904  10-12-2018      Swapnil              Delhi               Delhi
# ...

# %%
for x in m.columns:
    for y in m.columns:
        print(x,y)
# Out:
# Order_ID Order_ID
# Order_ID Order_Date
# Order_ID CustomerName
# Order_ID State
# Order_ID City
# Order_Date Order_ID
# Order_Date Order_Date
# Order_Date CustomerName
# Order_Date State
# Order_Date City
# CustomerName Order_ID
# CustomerName Order_Date
# CustomerName CustomerName
# CustomerName State
# CustomerName City
# State Order_ID
# State Order_Date
# State CustomerName
# State State
# State City
# City Order_ID
# City Order_Date
# City CustomerName
# City State
# City City

# %%
s.iloc[:,2]
# Out:
# 0        Harivansh
# 1           Madhav
# 2      Madan Mohan
# 3            Gopal
# 4         Vishakha
#           ...
# 495         Ashwin
# 496         Bhavna
# 497        Shivani
# 498        Shubham
# 499        Monisha
# Name: CustomerName, Length: 500, dtype: object

# %%
s.shape[1]
# Out:
# 5

# %%
v=pd.read_excel("C:/Users/akrit/Downloads/dup_columns.xlsx")

# %%
v
# Out:
#     id first_name last_name  age sex employee_title  department Gender
# 0    5        Max    George   26   M          Sales       Sales      M  \
# 1   13      Katty      Bond   56   F        Manager  Management      F
# 2   11    Richerd      Gear   57   M        Manager  Management      M
# 3   10   Jennifer      Dion   34   F          Sales       Sales      F
# 4   19     George       Joe   50   M        Manager  Management      M
# 5   18      Laila      Mark   26   F          Sales       Sales      F
# 6   20     Sarrah     Bicky   31   F   Senior Sales       Sales      F
# 7   21      Suzan       Lee   34   F          Sales       Sales      F
# 8   22      Mandy      John   31   F          Sales       Sales      F
# 9   23    Britney     Berry   45   F          Sales       Sales      F
# 10  25       Jack      Mick   29   M          Sales       Sales      M
# 11  26        Ben       Ten   43   M          Sales       Sales      M
# ...

# %%
for x in v.columns:
    for y in v.columns:
        print(x,y)
# Out:
# id id
# id first_name
# id last_name
# id age
# id sex
# id employee_title
# id department
# id Gender
# id salary
# id emp_id
# id Name
# first_name id
# first_name first_name
# first_name last_name
# first_name age
# first_name sex
# first_name employee_title
# first_name department
# first_name Gender
# first_name salary
# first_name emp_id
# first_name Name
# last_name id
# last_name first_name
# last_name last_name
# last_name age
# last_name sex
# last_name employee_title
# last_name department
# last_name Gender
# last_name salary
# last_name emp_id
# last_name Name
# age id
# age first_name
# age last_name
# age age
# age sex
# age employee_title
# age department
# age Gender
# age salary
# age emp_id
# age Name
# sex id
# sex first_name
# sex last_name
# sex age
# sex sex
# sex employee_title
# sex department
# sex Gender
# sex salary
# sex emp_id
# sex Name
# employee_title id
# employee_title first_name
# employee_title last_name
# employee_title age
# employee_title sex
# ...

# %%
v.sort_index(axis=1,ascending =True)
# Out:
#    Gender      Name  age  department  emp_id employee_title first_name  id
# 0       M       Max   26       Sales       5          Sales        Max   5  \
# 1       F     Katty   56  Management      13        Manager      Katty  13
# 2       M   Richerd   57  Management      11        Manager    Richerd  11
# 3       F  Jennifer   34       Sales      10          Sales   Jennifer  10
# 4       M    George   50  Management      19        Manager     George  19
# 5       F     Laila   26       Sales      18          Sales      Laila  18
# 6       F    Sarrah   31       Sales      20   Senior Sales     Sarrah  20
# 7       F     Suzan   34       Sales      21          Sales      Suzan  21
# 8       F     Mandy   31       Sales      22          Sales      Mandy  22
# 9       F   Britney   45       Sales      23          Sales    Britney  23
# 10      M      Jack   29       Sales      25          Sales       Jack  25
# ...

# %%
from faker import Faker
import pandas as p
import numpy as n

# %%
fake = Faker()

# %%
dd={}
mm=[]

# %%
fake.data_time_between_dates('-1y','now')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 fake.data_time_between_dates('-1y','now')
#
# File C:\Python311\Lib\site-packages\faker\proxy.py:111, in Faker.__getattr__(self, attr)
#     104 """
#     105 Handles cache access and proxying behavior
#     106
#     107 :param attr: attribute name
#     108 :return: the appropriate attribute
#     109 """
#     110 if len(self._factories) == 1:
# --> 111     return getattr(self._factories[0], attr)
#     112 elif attr in self.generator_attrs:
#     113     msg = "Proxying calls to `%s` is not implemented in multiple locale mode." % attr
#
# AttributeError: 'Generator' object has no attribute 'data_time_between_dates'

# %%
fake.name()
# Out:
# 'Rose Brown'

# %%
fake.zipcode()
# Out:
# '62280'

# %%
for x in range (10,20):
    print(n.random.randint(1000,800000000))
# Out:
# 387262576
# 200386813
# 312355771
# 699221606
# 163098241
# 150894197
# 402440022
# 466139420
# 345574659
# 37544186

# %%
for i in range(20):
for y  in range (i):   
dd.append(fake.name())
# Out:
#   Cell In[29], line 2
#     for y  in range (i):
#     ^
# IndentationError: expected an indented block after 'for' statement on line 1

# %%
dd
# Out:
# {}

# %%
dic ={"trandata":['03-09-2002 17:08','02-09-2002 05:33','09-09-2003 06:33'],
     "tranamount":['12324','213','3143'] }

# %%
d =p.DataFrame(dic)

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   trandata    3 non-null      object
#  1   tranamount  3 non-null      object
# dtypes: object(2)
# memory usage: 180.0+ bytes

# %%
d['trandata']=p.to_datetime(d['trandata'])

# %%
d['data_only']= d.trandata.dt.day_name()
d
# Out:
#              trandata tranamount data_only
# 0 2002-03-09 17:08:00      12324  Saturday
# 1 2002-02-09 05:33:00        213  Saturday
# 2 2003-09-09 06:33:00       3143   Tuesday

# %%
s=pd.read_csv("C:/Users/akrit/Downloads/mm.csv")

# %%
s
# Out:
#         Duration           Start date             End date
# 0           1012  2010-09-20 11:27:04  2010-09-20 11:43:56  \
# 1             61  2010-09-20 11:41:22  2010-09-20 11:42:23
# 2           2690  2010-09-20 12:05:37  2010-09-20 12:50:27
# 3           1406  2010-09-20 12:06:05  2010-09-20 12:29:32
# 4           1413  2010-09-20 12:10:43  2010-09-20 12:34:17
# ...          ...                  ...                  ...
# 115592      2179  2010-12-31 23:20:32  2010-12-31 23:56:52
# 115593       953  2010-12-31 23:21:57  2010-12-31 23:37:50
# 115594       737  2010-12-31 23:27:28  2010-12-31 23:39:45
# 115595       514  2010-12-31 23:37:38  2010-12-31 23:46:12
# 115596     51962  2010-12-31 23:49:05  2011-01-01 14:15:08
#
#         Start station number                  Start station
# 0                      31208       M St & New Jersey Ave SE  \
# 1                      31209                 1st & N St  SE
# 2                      31600                  5th & K St NW
# ...

# %%
s=s[['Start date']].sample(frac=1).head(6).reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 s=s[['Start date']].sample(frac=1).head(6).reset_index(drop=True)
#
# File C:\Python311\Lib\site-packages\pandas\core\frame.py:3766, in DataFrame.__getitem__(self, key)
#    3764     if is_iterator(key):
#    3765         key = list(key)
# -> 3766     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3768 # take() does not accept boolean indexers
#    3769 if getattr(indexer, "dtype", None) == bool:
#
# File C:\Python311\Lib\site-packages\pandas\core\indexes\base.py:5876, in Index._get_indexer_strict(self, key, axis_name)
#    5873 else:
#    5874     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5876 self._raise_if_missing(keyarr, indexer, axis_name)
#    5878 keyarr = self.take(indexer)
#    5879 if isinstance(key, Index):
# ...

# %%
s
# Out:
#             Start date
# 0  2010-10-30 19:31:03
# 1  2010-11-07 15:57:43
# 2  2010-11-05 11:21:44
# 3  2010-11-17 20:45:39
# 4  2010-09-25 15:15:35
# 5  2010-12-28 12:36:56

# %%
s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Start date  6 non-null      object
# dtypes: object(1)
# memory usage: 180.0+ bytes

# %%
s['Start date']=pd.to_datetime(s['Start date'])

# %%
# s['Start date'].dt.year

# %%
s['year']=s['Start date'].dt.year
s['month']=s['Start date'].dt.month
s['days']=s['Start date'].dt.day
s['time']=s['Start date'].dt.time

# %%
s
# Out:
#            Start date  year  month  days      time
# 0 2010-10-30 19:31:03  2010     10    30  19:31:03
# 1 2010-11-07 15:57:43  2010     11     7  15:57:43
# 2 2010-11-05 11:21:44  2010     11     5  11:21:44
# 3 2010-11-17 20:45:39  2010     11    17  20:45:39
# 4 2010-09-25 15:15:35  2010      9    25  15:15:35
# 5 2010-12-28 12:36:56  2010     12    28  12:36:56
